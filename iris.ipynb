# %%
from sklearn.datasets import load_iris

# %%
iris_dataset = load_iris()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(iris_dataset['data'], iris_dataset['target'], random_state=0)

# %%
import pandas as pd
iris_dataframe = pd.DataFrame(X_train, columns=iris_dataset.feature_names)

# %%
from pandas.plotting import scatter_matrix

# %%
grr = scatter_matrix(iris_dataframe, c=y_train, figsize=(15,15), marker='o', alpha=0.8)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
print('KNN score:{}'.format(knn.score(X_test, y_test)))
# Out:
# KNN score:0.9736842105263158

# %%
import numpy as np

# %%
X_new = np.array([[5,2.9,1,0.2]])

# %%
print('New Prediction:{}'.format(iris_dataset['target_names'][knn.predict(X_new)]))
# Out:
# New Prediction:['setosa']
